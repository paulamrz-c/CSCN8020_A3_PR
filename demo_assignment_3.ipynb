# %% [markdown]
# # **Demo - DQN**

# %%
from main import train
# Out:
# Running cells with 'venv (Python 3.12.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/paula/github-classroom/CSCN8020 - Reinforcement Learning/CSCN8020_A3_PR/venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
# --- Experimentos ---
batch_sizes = [8, 16]
update_rates = [10, 3]

for batch in batch_sizes:
    for rate in update_rates:
        print(f"\nTraining with batch size = {batch}, update rate = {rate}")
        train(episodes=100, batch_size=batch, update_rate=rate)
